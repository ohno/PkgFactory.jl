# %% [markdown]
# # {{{PKG}}}.jl — Quick start
#
# Run the cells from top to bottom. In Google Colab, choose **Runtime → Change runtime type → Julia** (CPU is sufficient).
#
# This package requires **Julia 1.12 or newer**. The notebook metadata selects Julia but does not install or pin its version. If Colab offers an older Julia runtime, use a Julia 1.12+ Jupyter kernel locally instead.
#
# The installation cell downloads this package from the public GitHub repository's `main` branch into the current directory's environment. The repository must be published first. The first run may take a few minutes; rerun setup after a runtime reset.

# %%
VERSION >= v"1.12" || error("Julia 1.12+ is required. Select a compatible Julia runtime or open this notebook locally with Julia 1.12+.")
println("Julia ", VERSION)

# %% [markdown]
# ## Install the package
#
# Activate the current directory's environment so that repeated runs reuse the same project. No GitHub token is required for a public repository.

# %%
import Pkg
Pkg.activate(".")
Pkg.add(url="https://github.com/{{{OWNER}}}/{{{PKG}}}.jl.git", rev="main")

# %%
import {{{PKG}}}

# %% [markdown]
# ## Run a first example
#
# Call the generated package's greeting function and check its result.

# %%
message = {{{PKG}}}.hello()
@assert message == "Hello, World!"
println(message)

# %% [markdown]
# ## Next steps
#
# Replace the example above with your own package API examples as it grows.
#
# - [Package repository](https://github.com/{{{OWNER}}}/{{{PKG}}}.jl)
# - [User guide](https://{{{OWNER}}}.github.io/{{{PKG}}}.jl/dev/user/)
#
# To save changes made in Colab, use **File → Save a copy in Drive** or download the notebook. The temporary runtime and package installation are not permanent.
